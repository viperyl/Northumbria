# %% [markdown]
# # Central limit theorem

# %% [markdown]
# ## Generate Uniformly Distributed Dice Random Numbers

# %%
import numpy as np 
import seaborn as sns
data = np.random.randint(1, 7, 10000)
sns.distplot(data)

# %%
sample1 = []
for i in range(0, 10):
    rnd = int(np.random.random() * len(data))
    sample1.append(data[rnd])
print(sample1)
# Out:
# [4, 2, 6, 6, 1, 1, 5, 1, 5, 1]

# %%
samples = []
s_mean = []

for i in range(0, 1000):
    sample = []
    for j in range(0, 50):
        rnd = int(np.random.random() * len(data))
        sample.append(data[rnd])
    s_mean.append(np.mean(sample))

sns.distplot(s_mean)
